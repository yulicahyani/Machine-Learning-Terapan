# %% [markdown]
# # **Sistem Rekomendasi**: Rekomendasi Buku untuk Pengguna
# ---
# ##### Proyek Submission 2 - Machine Learning Terapan
# ##### Oleh : Ni Made Yuli Cahyani
#
#
# <img src=https://user-images.githubusercontent.com/71582007/141651018-0a3c2e7a-e9b6-4402-be87-11dda8b103df.jpg>

# %% [markdown]
# # **Pendahuluan**
#
# Pada proyek ini akan dibuat sistem rekomendasi buku untuk pengguna menggunakan teknik *collaborative filtering*.

# %% [markdown]
# # **1. Mengimpor library python yang dibutuhkan**

# %%
import pandas as pd
import numpy as np 

import re
import string

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
import plotly.io as pio
pio.renderers.default = 'colab'
from wordcloud import WordCloud,STOPWORDS

from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # **2. Mempersiapkan Dataset**

# %% [markdown]
# ## 2.1 Menyiapkan kredensial akun Kaggle

# %%
# Membuat folder .kaggle di dalam folder root
# !rm -rf ~/.kaggle && mkdir ~/.kaggle/

# Menyalin berkas kaggle.json pada direktori aktif saat ini ke folder .kaggle
# !mv kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## 2.2 Mengunduh dan menyiapkan dataset

# %% [markdown]
# <p align="center">
#     <img width="719" alt="informasi-dataset" src="https://user-images.githubusercontent.com/71582007/141651042-5d94ef43-5aba-4568-8ca2-cb34496040ce.PNG">
# </p>
#
# Informasi Dataset :
#
# Jenis | Keterangan
# --- | ---
# Sumber | [Kaggle Dataset : Book-Crossing](https://www.kaggle.com/ruchi798/bookcrossing-dataset)
# Lisensi | CC0: Public Domain
# Kategori | Arts and Entertainment, Online Communities, Literature
# Rating Penggunaan | 10.0 (Gold)
# Jenis dan Ukuran Berkas | zip (600.34 MB)

# %%
# Mengunduh dataset menggunakan Kaggle CLI
# !kaggle datasets download -d ruchi798/bookcrossing-dataset
# Out:
# Downloading bookcrossing-dataset.zip to /content
#  96% 73.0M/76.1M [00:00<00:00, 71.5MB/s]
# 100% 76.1M/76.1M [00:00<00:00, 82.5MB/s]

# %%
# Mengekstrak berkas zip ke direktori aktif saat ini
# !unzip /content/bookcrossing-dataset.zip
# Out:
# Archive:  /content/bookcrossing-dataset.zip
#   inflating: Book reviews/Book reviews/BX-Book-Ratings.csv
#   inflating: Book reviews/Book reviews/BX-Users.csv
#   inflating: Book reviews/Book reviews/BX_Books.csv
#   inflating: Books Data with Category Language and Summary/Preprocessed_data.csv

# %% [markdown]
# # **3.** ***Data Understanding***

# %% [markdown]
# ## 3.1 Memuat data

# %%
path = '/content/Books Data with Category Language and Summary/Preprocessed_data.csv'
df = pd.read_csv(path)
df
# Out:
#          Unnamed: 0  user_id  ...       state  country
# 0                 0        2  ...  california      usa
# 1                 1        8  ...     ontario   canada
# 2                 2    11400  ...     ontario   canada
# 3                 3    11676  ...         NaN      NaN
# 4                 4    41385  ...     ontario   canada
# ...             ...      ...  ...         ...      ...
# 1031170     1031170   278851  ...       texas      usa
# 1031171     1031171   278851  ...       texas      usa
# 1031172     1031172   278851  ...       texas      usa
# 1031173     1031173   278851  ...       texas      usa
# 1031174     1031174   278851  ...       texas      usa
#
# [1031175 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'user_id', 'location', 'age', 'isbn', 'rating',
#        'book_title', 'book_author', 'year_of_publication', 'publisher',
#        'img_s', 'img_m', 'img_l', 'Summary', 'Language', 'Category', 'city',
#        'state', 'country'],
#       dtype='object')

# %% [markdown]
# **Observasi :** <br>
# Output kode di atas memberikan informasi sebagai berikut:
#
# *   Terdapat 1031175 baris (records atau jumlah pengamatan) dalam dataset.
# *   Terdapat 19 kolom yaitu: 'Unnamed: 0', 'user_id', 'location', 'age', 'isbn', 'rating', 'book_title', 'book_author', 'year_of_publication', 'publisher', 'img_s', 'img_m', 'img_l', 'Summary', 'Language', 'Category', 'city', 'state', 'country'.

# %% [markdown]
# ## 3.2 Deskripsi variabel pada data

# %% [markdown]
# **Deskripsi Variabel :** <br>
# Berdasarkan informasi dari Kaggle, variabel-variabel pada Book-Crossing dataset adalah sebagai berikut:
#
# 1. 'Unnamed: 0' - index pada data
# 2. 'user_id' - id dari pengguna
# 3. 'location' - lokasi/alamat pengguna
# 4. 'age' - umur pengguna
# 5. 'isbn' - kode ISBN (International Standard Book Number) buku
# 6. 'rating' - rating dari buku
# 7. 'book_title' - judul buku
# 8. 'book_author' - penulis buku
# 9. 'year_of_publication' - tahun terbit buku
# 10. 'publisher' - penerbit buku
# 11. 'img_s' - gambar sampul buku (small)
# 12. 'img_m' - gambar sampul buku (medium)
# 13. 'img_l' - gambar sampul buku (large)
# 14. 'Summary' - ringkasan/sinopsis buku
# 15. 'Language' - bahasa yang digunakan buku
# 16. 'Category' - kategori buku
# 17. 'city' - kota pengguna
# 18. 'state' - negara bagian penguna
# 19. 'country' - negara pengguna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031175 entries, 0 to 1031174
# Data columns (total 19 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   Unnamed: 0           1031175 non-null  int64
#  1   user_id              1031175 non-null  int64
#  2   location             1031175 non-null  object
#  3   age                  1031175 non-null  float64
#  4   isbn                 1031175 non-null  object
#  5   rating               1031175 non-null  int64
#  6   book_title           1031175 non-null  object
#  7   book_author          1031175 non-null  object
#  8   year_of_publication  1031175 non-null  float64
#  9   publisher            1031175 non-null  object
#  10  img_s                1031175 non-null  object
#  11  img_m                1031175 non-null  object
#  12  img_l                1031175 non-null  object
#  13  Summary              1031175 non-null  object
#  14  Language             1031175 non-null  object
#  15  Category             1031175 non-null  object
#  16  city                 1017072 non-null  object
#  17  state                1008377 non-null  object
#  18  country              995801 non-null   object
# dtypes: float64(2), int64(3), object(14)
# memory usage: 149.5+ MB

# %% [markdown]
# **Observasi :** <br>
# Output kode di atas memberikan informasi sebagai berikut:
#
# * Terdapat 3 kolom numerik dengan tipe data int64, yaitu: Unnamed: 0, user_id, rating. Ini merupakan fitur numerik. Tetapi untuk kolom Unnamed: 0 merupakan fitur yang tidak diperlukan dan bisa dibuang.
# * Terdapat 2 kolom numerik dengan tipe data float64 yaitu: age dan year_of_publication. Ini merupakan fitur numerik.
# * Terdapat 14 kolom dengan tipe object, yaitu: location, isbn, book_title,book_author, publisher, img_s, img_m, img_l, Summary, Language, Category, city, state, country. Kolom ini merupakan categorical features (fitur non-numerik) dimana kolom ini merupakan target fitur.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observasi :** <br>
# Output kode di atas memberikan informasi bahwa tidak terdapat data duplikat pada Book-Crossing dataset

# %% [markdown]
# # **4.** ***Data Preprocessing***

# %% [markdown]
# ## 4.1 Menghapus kolom/fitur yang tidak diperlukan

# %%
# menghapus kolom 'Unnamed: 0','img_s', 'img_m', 'img_l' pada data
df = df.drop(columns=['Unnamed: 0', 'img_s', 'img_m', 'img_l'])

# %% [markdown]
# **Observasi :** <br>
# Pada data terdapat kolom/fitur yang tidak diperlukan karena tidak akan berpengaruh pada proses pembuatan model sistem rekomendasi sehingga bisa dihapus atau dibuang. Kolom-kolom tersebut yaitu kolom 'Unnamed: 0', 'img_s', 'img_m', 'img_l'

# %% [markdown]
# ## 4.2 Mengganti tipe data pada kolom

# %%
# mengganti tipe data pada kolom year_of_publication dan age
df['year_of_publication'] = df['year_of_publication'].astype(int)
df['age'] = df['age'].astype(int)

# %% [markdown]
#  **Observasi :** <br>
# Berdasarkan deskripsi variabel sebelumnya, didapatkan bahwa terdapat 2 kolom yang bertipe data float yaitu kolom 'year_of_publication' dan 'age'. Pada tahap ini kedua kolom tersebut akan diubah menjadi tipe data int, hal ini dilakukan karena tipe data pada kolom tersebut belum sesuai dengan data di kolomnya.

# %% [markdown]
# ## 4.3 Membersihkan data kosong pada kolom

# %%
df.isna().sum()
# Out:
# user_id                    0
# location                   0
# age                        0
# isbn                       0
# rating                     0
# book_title                 0
# book_author                0
# year_of_publication        0
# publisher                  0
# Summary                    0
# Language                   0
# Category                   0
# city                   14103
# state                  22798
# country                35374
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Observasi :** <br>
# Output kode di atas memberikan informasi bahwa terdapat data kosong pada beberapa kolom yaitu kolom city dengan 14103 data kosong, state dengan 22798 data kosong dan country dengan 35374 data kosong. Kemudian karena jumlah data kosong jauh lebih sedikit dari total dataset yaitu 1031175, maka data kosong tersebut akan dihapus dari data menggunakan fungsi dropna.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982279 entries, 0 to 1031174
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              982279 non-null  int64
#  1   location             982279 non-null  object
#  2   age                  982279 non-null  int64
#  3   isbn                 982279 non-null  object
#  4   rating               982279 non-null  int64
#  5   book_title           982279 non-null  object
#  6   book_author          982279 non-null  object
#  7   year_of_publication  982279 non-null  int64
#  8   publisher            982279 non-null  object
#  9   Summary              982279 non-null  object
#  10  Language             982279 non-null  object
#  11  Category             982279 non-null  object
#  12  city                 982279 non-null  object
#  13  state                982279 non-null  object
#  14  country              982279 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 119.9+ MB

# %% [markdown]
# **Observasi :** <br>
# Setelah membersihkan data kosong maka jumlah data pada dataset berubah menjadi 982279 data.

# %% [markdown]
# ## 4.4 Text Cleaning pada data

# %%
# membuat text lowercase, remove text dalam tanda kurung siku, remove links, remove punctuation
# dan remove kata yang mengandung angka.
def clean_text(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df['book_title']
# Out:
# 0                                        Classical Mythology
# 1                                               Clara Callan
# 2                                               Clara Callan
# 4                                               Clara Callan
# 5                                               Clara Callan
#                                  ...
# 1031170    As Hogan Said . . . : The 389 Best Things Anyo...
# 1031171    All Elevations Unknown: An Adventure in the He...
# 1031172    Why stop?: A guide to Texas historical roadsid...
# 1031173    The Are You Being Served? Stories: 'Camping In...
# 1031174    Dallas Street Map Guide and Directory, 2000 Ed...
# Name: book_title, Length: 982279, dtype: object

# %%
# melakukan text cleaning pada kolom book_title
df['book_title'] = df['book_title'].apply(lambda x:clean_text(x))

# %% [markdown]
# **Observasi :** <br>
# Karena data text pada kolom book_title belum seragam dan masih mengandung tanda/karakter yang tidak diperlukan, maka dilakukan text cleaning pada kolom tersebut yang terdiri dari membuat text menjadi lowercase, remove text dalam tanda kurung siku, remove links, remove punctuation dan remove angka.

# %% [markdown]
# # **5.** ***Data Visualisation***

# %% [markdown]
# ## 5.1 Top 10 dari tahun penerbitan, penulis dan buku

# %%
# top 10 tahun penerbitan
top_year = df['year_of_publication'].value_counts().reset_index()
top_year.columns = ['value', 'count']
top_year['value'] = top_year['value'].astype(str) + ' year'
top_year = top_year.sort_values('count')
fig = px.bar(top_year.tail(10), x='count', y='value', title='Top 10 Tahun Penerbitan', orientation='h', color='value',
             width=800, height=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0065c064-2fbc-44cf-b061-0a7c53c82264" class="plotly-graph-div" style="height:900px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0065c064-2fbc-44cf-b061-0a7c53c82264")) {
#                     Plotly.newPlot(
#                         '0065c064-2fbc-44cf-b061-0a7c53c82264',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1995 year", "marker": {"color": "#636efa"}, "name": "value=1995 year", "offsetgroup": "value=1995 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [51592], "xaxis": "x", "y": ["1995 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1996 year", "marker": {"color": "#EF553B"}, "name": "value=1996 year", "offsetgroup": "value=1996 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [56083], "xaxis": "x", "y": ["1996 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1997 year", "marker": {"color": "#00cc96"}, "name": "value=1997 year", "offsetgroup": "value=1997 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [56526], "xaxis": "x", "y": ["1997 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1994 year", "marker": {"color": "#ab63fa"}, "name": "value=1994 year", "offsetgroup": "value=1994 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [57449], "xaxis": "x", "y": ["1994 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1998 year", "marker": {"color": "#FFA15A"}, "name": "value=1998 year", "offsetgroup": "value=1998 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [61124], "xaxis": "x", "y": ["1998 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=2000 year", "marker": {"color": "#19d3f3"}, "name": "value=2000 year", "offsetgroup": "value=2000 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [68688], "xaxis": "x", "y": ["2000 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=2003 year", "marker": {"color": "#FF6692"}, "name": "value=2003 year", "offsetgroup": "value=2003 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [69009], "xaxis": "x", "y": ["2003 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=1999 year", "marker": {"color": "#B6E880"}, "name": "value=1999 year", "offsetgroup": "value=1999 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [71430], "xaxis": "x", "y": ["1999 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=2001 year", "marker": {"color": "#FF97FF"}, "name": "value=2001 year", "offsetgroup": "value=2001 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [75849], "xaxis": "x", "y": ["2001 year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=2002 year", "marker": {"color": "#FECB52"}, "name": "value=2002 year", "offsetgroup": "value=2002 year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [87088], "xaxis": "x", "y": ["2002 year"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 900, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"out

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas didapatkan informasi bahwa top 10 tahun penerbitan yaitu pada tahun 1995, 1996, 1997, 1994, 1998, 2000, 2003, 1999, 2001 dan 2002. Kemudian tahun 2002 merupakan tahun dengan jumlah buku terbit paling tinggi, dimana jumlah buku yang terbit pada tahun itu sebesar 87.088K.

# %%
# top 10 penulis
top_author = df['book_author'].value_counts().reset_index()
top_author.columns = ['value', 'count']
top_author['value'] = top_author['value']
top_author = top_author.sort_values('count')
fig = px.bar(top_author.tail(10), x="count", y="value", title='Top 10 Penulis', orientation='h', color='value',
             width=800, height=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ad13e1a1-f4a9-43be-95ca-4be587319c1e" class="plotly-graph-div" style="height:900px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad13e1a1-f4a9-43be-95ca-4be587319c1e")) {
#                     Plotly.newPlot(
#                         'ad13e1a1-f4a9-43be-95ca-4be587319c1e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Janet Evanovich", "marker": {"color": "#636efa"}, "name": "value=Janet Evanovich", "offsetgroup": "value=Janet Evanovich", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3166], "xaxis": "x", "y": ["Janet Evanovich"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Sue Grafton", "marker": {"color": "#EF553B"}, "name": "value=Sue Grafton", "offsetgroup": "value=Sue Grafton", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3316], "xaxis": "x", "y": ["Sue Grafton"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Danielle Steel", "marker": {"color": "#00cc96"}, "name": "value=Danielle Steel", "offsetgroup": "value=Danielle Steel", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3544], "xaxis": "x", "y": ["Danielle Steel"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Tom Clancy", "marker": {"color": "#ab63fa"}, "name": "value=Tom Clancy", "offsetgroup": "value=Tom Clancy", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3869], "xaxis": "x", "y": ["Tom Clancy"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Dean R. Koontz", "marker": {"color": "#FFA15A"}, "name": "value=Dean R. Koontz", "offsetgroup": "value=Dean R. Koontz", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4129], "xaxis": "x", "y": ["Dean R. Koontz"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Mary Higgins Clark", "marker": {"color": "#19d3f3"}, "name": "value=Mary Higgins Clark", "offsetgroup": "value=Mary Higgins Clark", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4520], "xaxis": "x", "y": ["Mary Higgins Clark"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=James Patterson", "marker": {"color": "#FF6692"}, "name": "value=James Patterson", "offsetgroup": "value=James Patterson", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5566], "xaxis": "x", "y": ["James Patterson"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=John Grisham", "marker": {"color": "#B6E880"}, "name": "value=John Grisham", "offsetgroup": "value=John Grisham", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5747], "xaxis": "x", "y": ["John Grisham"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Nora Roberts", "marker": {"color": "#FF97FF"}, "name": "value=Nora Roberts", "offsetgroup": "value=Nora Roberts", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8052], "xaxis": "x", "y": ["Nora Roberts"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=Stephen King", "marker": {"color": "#FECB52"}, "name": "value=Stephen King", "offsetgroup": "value=Stephen King", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [9679], "xaxis": "x", "y": ["Stephen King"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 900, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automar

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas didapatkan informasi bahwa top 10 penulis yaitu Janet Evanovich, Sue Grafton, Danielle Steel, Tom Clancy, Dean R. Knoontz, Marry Higgins Clark, James Patterson, John Grisham, Nora Roberts dan Stephen King. Kemudian Stephen King merupakan penulis dengan jumlah buku paling tinggi, dimana jumlah buku yang ditulis sebanyak 9679 buku.

# %%
# top 10 buku
top_book = df['book_title'].value_counts().reset_index()
top_book.columns = ['value', 'count']
top_book['value'] = top_book['value']
top_book = top_book.sort_values('count')
fig = px.bar(top_book.tail(10), x="count", y="value", title='Top Books', orientation='h', color='value',
             width=800, height=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb5ed151-eb99-4c2a-9344-0633eb79bc27" class="plotly-graph-div" style="height:900px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb5ed151-eb99-4c2a-9344-0633eb79bc27")) {
#                     Plotly.newPlot(
#                         'bb5ed151-eb99-4c2a-9344-0633eb79bc27',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=angels  demons", "marker": {"color": "#636efa"}, "name": "value=angels  demons", "offsetgroup": "value=angels  demons", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [654], "xaxis": "x", "y": ["angels  demons"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=the red tent bestselling backlist", "marker": {"color": "#EF553B"}, "name": "value=the red tent bestselling backlist", "offsetgroup": "value=the red tent bestselling backlist", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [687], "xaxis": "x", "y": ["the red tent bestselling backlist"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=divine secrets of the yaya sisterhood a novel", "marker": {"color": "#00cc96"}, "name": "value=divine secrets of the yaya sisterhood a novel", "offsetgroup": "value=divine secrets of the yaya sisterhood a novel", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [716], "xaxis": "x", "y": ["divine secrets of the yaya sisterhood a novel"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=the secret life of bees", "marker": {"color": "#ab63fa"}, "name": "value=the secret life of bees", "offsetgroup": "value=the secret life of bees", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [742], "xaxis": "x", "y": ["the secret life of bees"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=bridget joness diary", "marker": {"color": "#FFA15A"}, "name": "value=bridget joness diary", "offsetgroup": "value=bridget joness diary", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [778], "xaxis": "x", "y": ["bridget joness diary"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=the nanny diaries a novel", "marker": {"color": "#19d3f3"}, "name": "value=the nanny diaries a novel", "offsetgroup": "value=the nanny diaries a novel", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [788], "xaxis": "x", "y": ["the nanny diaries a novel"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=a painted house", "marker": {"color": "#FF6692"}, "name": "value=a painted house", "offsetgroup": "value=a painted house", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [799], "xaxis": "x", "y": ["a painted house"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=the da vinci code", "marker": {"color": "#B6E880"}, "name": "value=the da vinci code", "offsetgroup": "value=the da vinci code", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [871], "xaxis": "x", "y": ["the da vinci code"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{y}<br>count=%{x}", "legendgroup": "value=the lovely bones a novel", "marker": {"color": "#FF97FF"}, "name": "value=the lovely bones a novel", "offsetgroup": "value=the lovely bones a novel", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1205], "xaxis": "x", "y": ["the lovely bones a novel"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "value=%{ ...
#                         {"barmode": "relative", "height": 900, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas didapatkan informasi bahwa top 10 buku yaitu angels demons, the red tent bestselling backlist, divine secrets of the yaya sisterhood a novel, the secret life of beees, bridget joness diary, the nanny diaries a novel, a painted house, the davinci code, the lonely bones a novel dan wild animus. Kemudian wild animus merupakan buku yang paling diminati dengan jumlah pembaca paling tinggi yaitu 2381 pembaca.

# %% [markdown]
# ## 5.2 Distribusi rating buku dan umur user

# %%
# distribusi rating
df['rating'].value_counts().iplot(kind='bar',
                                         xTitle='Rating',
                                         yTitle='Counts',
                                         title='Distribusi Rating',
                                         color='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c4b63e57-1d4d-490f-9507-69de95ad3aac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c4b63e57-1d4d-490f-9507-69de95ad3aac")) {
#                     Plotly.newPlot(
#                         'c4b63e57-1d4d-490f-9507-69de95ad3aac',
#                         [{"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "rating", "orientation": "v", "text": "", "type": "bar", "x": [0, 8, 10, 7, 9, 5, 6, 4, 3, 2, 1], "y": [622808, 86050, 66644, 62177, 57331, 42566, 29516, 7010, 4698, 2174, 1305]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas didapatkan informasi bahwa nilai pada kolom rating berada pada rentang 0 - 10. Pada hasil visualisai juga terlihat sebagian besar buku memiliki rating 0.

# %%
# distribusi umur
df['age'].value_counts().iplot(kind='bar',
                                         xTitle='Umur',
                                         yTitle='Counts',
                                         title='Distribusi Umur (age)',
                                         color='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43cd9b0e-3914-475e-82fd-13f72532019e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("43cd9b0e-3914-475e-82fd-13f72532019e")) {
#                     Plotly.newPlot(
#                         '43cd9b0e-3914-475e-82fd-13f72532019e',
#                         [{"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "age", "orientation": "v", "text": "", "type": "bar", "x": [34, 33, 29, 30, 32, 36, 28, 31, 27, 38, 26, 44, 25, 37, 43, 35, 23, 47, 24, 52, 46, 39, 41, 40, 49, 51, 45, 22, 42, 21, 54, 50, 58, 57, 18, 62, 56, 48, 53, 20, 55, 19, 17, 61, 65, 60, 16, 14, 15, 59, 67, 9, 63, 13, 69, 66, 64, 12, 68, 71, 8, 11, 70, 72, 73, 76, 74, 10, 81, 75, 80, 83, 7, 77, 5, 79, 97, 78, 92, 84, 82, 93, 85, 96, 6, 99, 86, 89, 98, 95, 94, 90], "y": [279004, 32336, 29770, 26608, 25943, 25533, 25215, 25100, 21846, 21825, 21651, 21308, 21235, 20843, 20455, 18942, 18210, 18127, 17892, 17264, 16235, 16047, 15677, 15006, 13746, 13622, 11574, 11566, 10488, 9804, 9787, 9233, 8783, 8697, 8470, 8355, 8276, 7497, 6714, 6244, 5896, 5107, 4900, 4183, 3692, 3473, 3144, 3075, 3022, 2840, 2771, 2056, 1896, 1217, 1200, 1174, 1036, 746, 698, 653, 542, 513, 504, 371, 265, 227, 227, 215, 214, 185, 182, 165, 148, 148, 146, 141, 127, 81, 47, 35, 25, 18, 17, 12, 6, 3, 2, 2, 1, 1, 1, 1]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas didapatkan informasi bahwa umur pengguna/user berada pada rentang 5 - 99 tahun. Pada hasil visualisai juga terlihat sebagian besar pengguna berada pada umur 34 tahun.

# %% [markdown]
# ## 5.3 Wordcloud pada judul, penulis dan penerbit buku

# %%
def wordcloud(string):
    wc = WordCloud(width=800,height=500,mask=None,random_state=21, max_font_size=110,stopwords=stop_words).generate(string)
    fig=plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(wc)

# %%
stop_words=set(STOPWORDS)
author_string = " ".join(df['book_author'].astype(str))
title_string = " ".join(df['book_title'].astype(str))
publisher_string = " ".join(df['publisher'].astype(str))

# %%
wordcloud(author_string)

# %%
wordcloud(title_string)

# %%
wordcloud(publisher_string)

# %% [markdown]
# **Observasi :** <br>
# Dari hasil visualisasi di atas menunjukkan daftar kata-kata yang digunakan dalam dalam kolom book_author, book_title dan publisher, umumnya semakin banyak kata yang digunakan semakin besar ukuran kata tersebut dalam visualisasi. Pada visualisai terlihat bahwa kata-kata yang paling banyak muncul pada kolom book_author yaitu Stephen King dan King Stephen, pada kolom book_title yaitu novels paperback dan mysteries paperback dan pada kolom publisher yaitu Ballantine Books dan Publishing Group.

# %% [markdown]
# # **6.** ***Data Preparation***

# %% [markdown]
# ## 6.1 K-Nearest Neighbor

# %% [markdown]
# ### 6.1.1 Filtering data buku dengan jumlah rating >= threshold (30)

# %%
model_knn_df = df.copy()

#menghitung jumlah rating pada setiap buku
number_of_ratings = model_knn_df.groupby('isbn')['rating'].count().reset_index()
number_of_ratings.rename(columns={'rating': 'number of book-rating'}, inplace=True)

#menggabungkan data dengan number_of_ratings
model_knn_df = model_knn_df.merge(number_of_ratings, on='isbn')
model_knn_df
# Out:
#         user_id                   location  ...  country number of book-rating
# 0             2  stockton, california, usa  ...      usa                     1
# 1             8   timmins, ontario, canada  ...   canada                    12
# 2         11400    ottawa, ontario, canada  ...   canada                    12
# 3         41385   sudbury, ontario, canada  ...   canada                    12
# 4         67544   toronto, ontario, canada  ...   canada                    12
# ...         ...                        ...  ...      ...                   ...
# 982274   278851         dallas, texas, usa  ...      usa                     1
# 982275   278851         dallas, texas, usa  ...      usa                     1
# 982276   278851         dallas, texas, usa  ...      usa                     1
# 982277   278851         dallas, texas, usa  ...      usa                     1
# 982278   278851         dallas, texas, usa  ...      usa                     1
#
# [982279 rows x 16 columns]

# %%
# Filtering data buku dengan jumlah rating >= threshold (30)
model_knn_df = model_knn_df[model_knn_df['number of book-rating'] >= 30]
model_knn_df.shape
# Out:
# (293037, 16)

# %% [markdown]
# **Observasi :** <br>
# Dari data dapat dilihat bahwa hanya sekitar 293.037 dari 982.279 buku yang mendapat rating oleh lebih dari 30 pengguna dan sebagian besar sisanya kurang dikenal dengan sedikit atau tanpa interaksi pengguna yang disebut sparse rating (sparse data). Sparse rating ini kurang dapat diprediksi untuk sebagian besar pengguna, dan menjadi noise pada data. Untuk menghilangkan pola noise dan menghindari "memory error" karena kumpulan data besar, maka dilakukan proses filtering rating buku hanya untuk buku populer dimana data buku yang akan digunakan hanya buku-buku yang mendapatkan rating oleh lebih dari 30 pengguna. Setelah memfilter data, jumlah data yang digunakan menjadi 293.037 data.

# %% [markdown]
# ### 6.1.2 Mengubah format data menjadi pivot tabel

# %%
#mengubah format data menjadai matrix 2 dimensi dengan fungsi pivot_table
model_knn_df_pivot = model_knn_df.pivot_table(columns='user_id', index='book_title', values='rating')
model_knn_df_pivot.fillna(0, inplace=True)
model_knn_df_pivot
# Out:
# user_id                                             8       ...  278854
# book_title                                                  ...
#                                                        0.0  ...     0.0
#  blondes                                               0.0  ...     0.0
#  chance                                                0.0  ...     0.0
#  charing cross road                                    0.0  ...     0.0
#  degree                                                0.0  ...     0.0
# ...                                                    ...  ...     ...
# your oasis on flame lake ballantine readers circle     0.0  ...     0.0
# yukon ho                                               0.0  ...     0.0
# zen and the art of motorcycle maintenance an in...     0.0  ...     0.0
# zodiac the ecothriller                                 0.0  ...     0.0
# zoya                                                   0.0  ...     0.0
#
# [3602 rows x 46833 columns]

# %%
model_knn_df_pivot.shape
# Out:
# (3602, 46833)

# %% [markdown]
# **Observasi :** <br>
# Pada tahap ini data rating buku akan di reshape ke dalam m x n array, dimana m merupakan jumlah buku dan n merupakan jumlah user, hal tersebut dapat meringkas nilai fitur pada dataframe ke dalam tabel dua dimensi yang rapi (pivot tabel) dengan judul buku (kolom book_title) menjadi indeks tabel, id user (kolom user_id) menjadi kolom tabel dan kolom rating menjadi nilai pada setiap baris tabel. Kemudian selanjutnya kita akan mengisi pengamatan yang hilang (data kosong) dengan nilai nol.

# %% [markdown]
# ### 6.1.3 Mengkonversi value (rating) pada pivot tabel ke dalam scipy sparse matrix

# %%
#mengkonversi nilai rating pada pivot tabel ke dalam scipy sparse matrix
book_csr_matrix = csr_matrix(model_knn_df_pivot)
book_csr_matrix
# Out:
# <3602x46833 sparse matrix of type '<class 'numpy.float64'>'
# 	with 113920 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Observasi :** <br>
# Data dalam pivot tabel dapat dikatakan sebagai sparse matrix dengan shape 3602 x 46833. Sparse matrix merupakan matrix yang sebagian besar nilainya adalah nol. Tentu saja kita tidak ingin mengumpankan seluruh data dengan sebagian besar bernilai nol dalam tipe data float32 ke model KNN yang akan dibuat. Oleh karena itu untuk perhitungan yang lebih efisien dan mengurangi memory footprint, kita perlu mengubah nilai pada pivot tabel menjadi scipy sparse matrix

# %% [markdown]
# ## 6.2 Deep learning atau Neural Network

# %% [markdown]
# ### 6.2.1 Proses encoding fitur user_id dan isbn ke dalam indeks integer

# %%
model_dl_df = df.copy()

# Melakukan proses encoding user_id
user_ids = model_dl_df["user_id"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}

# Melakukan proses encoding isbn
book_ids = model_dl_df["isbn"].unique().tolist()
book2book_encoded = {x: i for i, x in enumerate(book_ids)}
book_encoded2book = {i: x for i, x in enumerate(book_ids)}

# Memetakan user_id dan isbn ke dataframe yang berkaitan.
model_dl_df["user"] = model_dl_df["user_id"].map(user2user_encoded)
model_dl_df["book"] = model_dl_df["isbn"].map(book2book_encoded)

num_users = len(user2user_encoded)
num_books = len(book_encoded2book)
model_dl_df["rating"] = model_dl_df["rating"].values.astype(np.float32)

# nilai min and max ratings
min_rating = min(model_dl_df["rating"])
max_rating = max(model_dl_df["rating"])

print("Number of users: {}, Number of Books: {}, Min rating: {}, Max rating: {}".format(num_users, num_books, min_rating, max_rating))
# Out:
# Number of users: 86927, Number of Books: 264662, Min rating: 0.0, Max rating: 10.0

# %% [markdown]
# **Observasi :** <br>
# Pada tahap ini akan dilakukan proses encoding yaitu proses mengubah data non-numerik menjadi data numerik agar model dapat memproses data tersebut. Pada proyek ini, proses encoding dilakukan pada fitur user_id dan isbn dengan memanfaatkan fungsi enumerate. Kemudian memetakan user_id dan isbn ke dataframe yang berkaitan.

# %% [markdown]
# ### 6.2.2 Pembagian Data untuk Training dan Validasi

# %%
# Mengacak dataset
model_dl_df = model_dl_df.sample(frac=1, random_state=42)
model_dl_df
# Out:
#         user_id                                   location  ...   user    book
# 812571   149909             sungai petani, kedah, malaysia  ...  15122  120070
# 204175    74080  duesseldorf, nordrhein-westfalen, germany  ...  38587    7059
# 361064   179809                   toronto, ontario, canada  ...  52366   17286
# 421248   123055                sacramento, california, usa  ...  15501   23499
# 407734   142209                       freeport, texas, usa  ...  55638   22014
# ...         ...                                        ...  ...    ...     ...
# 272214   236757                    mars, pennsylvania, usa  ...   3909   11075
# 384313   125474                        wien, wien, austria  ...  12498   19532
# 138545   190925                   hobe sound, florida, usa  ...   2212    3557
# 708557    41589                bellingham, washington, usa  ...   4747   81870
# 128119   100459                  bay area, california, usa  ...    536    3136
#
# [982279 rows x 17 columns]

# %%
# Membuat variabel x untuk mencocokkan data user dan buku menjadi satu value
x = model_dl_df[["user", "book"]].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = model_dl_df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %%
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((785823, 2), (196456, 2), (785823,), (196456,))

# %% [markdown]
# **Observasi :** <br>
# Pada tahap ini dilakukan pembagian data menjadi data training dan validasi. Namun sebelum itu, kita perlu mengacak datanya terlebih dahulu agar distribusinya menjadi random. Kemudian membuat variabel x untuk mencocokkan data user dan buku menjadi satu value, lalu membuat variabel y untuk membuat rating dari hasil. Setelah itu membagi menjadi 80% data train dan 20% data validasi. Setelah melakukan pembagian dataset, didapatkan jumlah sample pada data train yaitu 785823 sampel dan jumlah sample pada data validasi yaitu 196456 sampel.

# %% [markdown]
# # **7.** ***Model Development - Collaborative Filtering***

# %% [markdown]
# ## 7.1 K-Nearest Neighbor

# %%
# inisialisai model
model_knn = NearestNeighbors(metric = 'cosine', algorithm='brute')
model_knn.fit(book_csr_matrix)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
book_df_name = pd.DataFrame({'Book':model_knn_df['book_title']})

# %%
book_df_name.duplicated().sum()
# Out:
# 289435

# %%
book_df_name.drop_duplicates(inplace=True)
book_df_name
# Out:
#                                                      Book
# 28                                  the kitchen gods wife
# 90                                          the testament
# 501                    beloved plume contemporary fiction
# 692     new vegetarian bold and beautiful recipes for ...
# 740                                           wild animus
# ...                                                   ...
# 670972  fleeced  a regan reilly mystery regan reilly m...
# 691144                                    tricky business
# 740169  the renegades of pern dragonriders of pern pap...
# 745448                                              years
# 745517                                something wonderful
#
# [3602 rows x 1 columns]

# %%
# fungsi untuk mendapatkan rekomendasi
def recomend_book(book_name):
    book_id = np.where(model_knn_df_pivot.index == book_name)[0][0]
    distances, recommendations = model_knn.kneighbors(model_knn_df_pivot.iloc[book_id,:].values.reshape(1,-1),  n_neighbors = 11)
    
    book = []
    distance = []

    for i in range(0, len(distances.flatten())):
      if i != 0:
        book.append(model_knn_df_pivot.index[recommendations.flatten()[i]])
        distance.append(distances.flatten()[i])    

    b = pd.Series(book,name='book')
    d = pd.Series(distance,name='distance')
    recommend = pd.concat([b,d], axis=1)
    recommend = recommend.sort_values('distance',ascending=False)

    print(f'10 rekomendasi untuk buku {book_name} sebagai berikut :\n')
    for i in range(0,recommend.shape[0]):
      print('{0}: {1}, with distance of {2}'.format(i, recommend["book"].iloc[i], recommend["distance"].iloc[i]))

# %%
book_name = book_df_name.iloc[100][0]
recomend_book(book_name)
# Out:
# 10 rekomendasi untuk buku the rescue sebagai berikut :
#
# 0: luckys lady, with distance of 0.9162800364263406
# 1: come the spring clayborne brothers, with distance of 0.9114173134942752
# 2: the wedding, with distance of 0.9038276080935737
# 3: this heart of mine avon romance, with distance of 0.8985689272966876
# 4: the notebook, with distance of 0.8960505573027107
# 5: message in a bottle, with distance of 0.8808803747806075
# 6: the guardian, with distance of 0.8787461786558258
# 7: a bend in the road, with distance of 0.8716456703951239
# 8: nights in rodanthe, with distance of 0.8631070098517125
# 9: a walk to remember, with distance of 0.8082340103878292

# %% [markdown]
# **Observasi :** <br>
# Dengan model K-Nearest Neighbor, kita mendapatkan 10 buku hasil rekomendasi terhadap buku dengan judul 'the rescue' dengan distance > 0.80

# %% [markdown]
# ## 7.1 Deep learning atau Neural Network

# %%
class RecommenderNet(keras.Model):
    def __init__(self, num_users, num_books, embedding_size, **kwargs):
        super(RecommenderNet, self).__init__(**kwargs)
        self.num_users = num_users
        self.num_books = num_books
        self.embedding_size = embedding_size
        self.user_embedding = layers.Embedding(
            num_users,
            embedding_size,
            embeddings_initializer="he_normal",
            embeddings_regularizer=keras.regularizers.l2(1e-6),
        )
        self.user_bias = layers.Embedding(num_users, 1)
        self.book_embedding = layers.Embedding(
            num_books,
            embedding_size,
            embeddings_initializer="he_normal",
            embeddings_regularizer=keras.regularizers.l2(1e-6),
        )
        self.book_bias = layers.Embedding(num_books, 1)

    def call(self, inputs):
        user_vector = self.user_embedding(inputs[:, 0])
        user_bias = self.user_bias(inputs[:, 0])
        book_vector = self.book_embedding(inputs[:, 1])
        book_bias = self.book_bias(inputs[:, 1])
        dot_user_book = tf.tensordot(user_vector, book_vector, 2)
        # Add all the components (including bias)
        x = dot_user_book + user_bias + book_bias
        # The sigmoid activation forces the rating to between 0 and 1
        return tf.nn.sigmoid(x)

# %%
# inisialisasi model
EMBEDDING_SIZE = 16
model = RecommenderNet(num_users, num_books, EMBEDDING_SIZE)

# %%
# model compile
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(), 
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=1000,
    epochs=200,
    verbose=1,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/200
# 786/786 [==============================] - 55s 68ms/step - loss: 0.6827 - root_mean_squared_error: 0.4370 - val_loss: 0.6383 - val_root_mean_squared_error: 0.4110
# Epoch 2/200
# 786/786 [==============================] - 55s 71ms/step - loss: 0.5911 - root_mean_squared_error: 0.3835 - val_loss: 0.5873 - val_root_mean_squared_error: 0.3811
# Epoch 3/200
# 786/786 [==============================] - 55s 69ms/step - loss: 0.5835 - root_mean_squared_error: 0.3794 - val_loss: 0.5862 - val_root_mean_squared_error: 0.3804
# Epoch 4/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5796 - root_mean_squared_error: 0.3773 - val_loss: 0.5829 - val_root_mean_squared_error: 0.3785
# Epoch 5/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5757 - root_mean_squared_error: 0.3752 - val_loss: 0.5795 - val_root_mean_squared_error: 0.3766
# Epoch 6/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5719 - root_mean_squared_error: 0.3731 - val_loss: 0.5757 - val_root_mean_squared_error: 0.3745
# Epoch 7/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5682 - root_mean_squared_error: 0.3711 - val_loss: 0.5728 - val_root_mean_squared_error: 0.3728
# Epoch 8/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5646 - root_mean_squared_error: 0.3692 - val_loss: 0.5703 - val_root_mean_squared_error: 0.3713
# Epoch 9/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5612 - root_mean_squared_error: 0.3674 - val_loss: 0.5666 - val_root_mean_squared_error: 0.3693
# Epoch 10/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5578 - root_mean_squared_error: 0.3655 - val_loss: 0.5645 - val_root_mean_squared_error: 0.3681
# Epoch 11/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5546 - root_mean_squared_error: 0.3638 - val_loss: 0.5617 - val_root_mean_squared_error: 0.3665
# Epoch 12/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5516 - root_mean_squared_error: 0.3621 - val_loss: 0.5592 - val_root_mean_squared_error: 0.3651
# Epoch 13/200
# 786/786 [==============================] - 52s 66ms/step - loss: 0.5486 - root_mean_squared_error: 0.3605 - val_loss: 0.5569 - val_root_mean_squared_error: 0.3639
# Epoch 14/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5457 - root_mean_squared_error: 0.3590 - val_loss: 0.5542 - val_root_mean_squared_error: 0.3624
# Epoch 15/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5430 - root_mean_squared_error: 0.3575 - val_loss: 0.5523 - val_root_mean_squared_error: 0.3614
# Epoch 16/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5403 - root_mean_squared_error: 0.3560 - val_loss: 0.5501 - val_root_mean_squared_error: 0.3602
# Epoch 17/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.5378 - root_mean_squared_error: 0.3546 - val_loss: 0.5477 - val_root_mean_squared_error: 0.3589
# Epoch 18/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5354 - root_mean_squared_error: 0.3534 - val_loss: 0.5464 - val_root_mean_squared_error: 0.3582
# Epoch 19/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5330 - root_mean_squared_error: 0.3521 - val_loss: 0.5437 - val_root_mean_squared_error: 0.3568
# Epoch 20/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5307 - root_mean_squared_error: 0.3508 - val_loss: 0.5427 - val_root_mean_squared_error: 0.3563
# Epoch 21/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5285 - root_mean_squared_error: 0.3496 - val_loss: 0.5405 - val_root_mean_squared_error: 0.3551
# Epoch 22/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.5265 - root_mean_squared_error: 0.3485 - val_loss: 0.5394 - val_root_mean_squared_error: 0.3545
# Epoch 23/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.5244 - root_mean_squared_error: 0.3474 - val_loss: 0.5372 - val_root_mean_squared_error: 0.3535
# Epoch 24/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5224 - root_mean_squared_error: 0.3464 - val_loss: 0.5359 - val_root_mean_squared_error: 0.3528
# Epoch 25/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.5206 - root_mean_squared_error: 0.3453 - val_loss: 0.5343 - val_root_mean_squared_error: 0.3520
# Epoch 26/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5187 - root_mean_squared_error: 0.3444 - val_loss: 0.5331 - val_root_mean_squared_error: 0.3514
# Epoch 27/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5170 - root_mean_squared_error: 0.3434 - val_loss: 0.5327 - val_root_mean_squared_error: 0.3512
# Epoch 28/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5153 - root_mean_squared_error: 0.3425 - val_loss: 0.5312 - val_root_mean_squared_error: 0.3505
# Epoch 29/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.5136 - root_mean_squared_error: 0.3416 - val_loss: 0.5301 - val_root_mean_squared_error: 0.3499
# Epoch 30/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5121 - root_mean_squared_error: 0.3408 - val_loss: 0.5290 - val_root_mean_squared_error: 0.3494
# Epoch 31/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.5106 - root_mean_squared_error: 0.3400 - val_loss: 0.5277 - val_root_mean_squared_error: 0.3488
# Epoch 32/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.5091 - root_mean_squared_error: 0.3392 - val_loss: 0.5264 - val_root_mean_squared_error: 0.3482
# Epoch 33/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.5077 - root_mean_squared_error: 0.3384 - val_loss: 0.5255 - val_root_mean_squared_error: 0.3477
# Epoch 34/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5063 - root_mean_squared_error: 0.3376 - val_loss: 0.5244 - val_root_mean_squared_error: 0.3472
# Epoch 35/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5050 - root_mean_squared_error: 0.3369 - val_loss: 0.5241 - val_root_mean_squared_error: 0.3470
# Epoch 36/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5036 - root_mean_squared_error: 0.3362 - val_loss: 0.5227 - val_root_mean_squared_error: 0.3464
# Epoch 37/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.5024 - root_mean_squared_error: 0.3355 - val_loss: 0.5225 - val_root_mean_squared_error: 0.3463
# Epoch 38/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.5012 - root_mean_squared_error: 0.3348 - val_loss: 0.5213 - val_root_mean_squared_error: 0.3457
# Epoch 39/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.5000 - root_mean_squared_error: 0.3342 - val_loss: 0.5210 - val_root_mean_squared_error: 0.3455
# Epoch 40/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4988 - root_mean_squared_error: 0.3335 - val_loss: 0.5197 - val_root_mean_squared_error: 0.3450
# Epoch 41/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.4977 - root_mean_squared_error: 0.3329 - val_loss: 0.5194 - val_root_mean_squared_error: 0.3448
# Epoch 42/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4966 - root_mean_squared_error: 0.3323 - val_loss: 0.5184 - val_root_mean_squared_error: 0.3443
# Epoch 43/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4956 - root_mean_squared_error: 0.3317 - val_loss: 0.5178 - val_root_mean_squared_error: 0.3440
# Epoch 44/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4945 - root_mean_squared_error: 0.3311 - val_loss: 0.5170 - val_root_mean_squared_error: 0.3437
# Epoch 45/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4935 - root_mean_squared_error: 0.3306 - val_loss: 0.5163 - val_root_mean_squared_error: 0.3434
# Epoch 46/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4925 - root_mean_squared_error: 0.3300 - val_loss: 0.5156 - val_root_mean_squared_error: 0.3430
# Epoch 47/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4916 - root_mean_squared_error: 0.3295 - val_loss: 0.5156 - val_root_mean_squared_error: 0.3430
# Epoch 48/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4906 - root_mean_squared_error: 0.3289 - val_loss: 0.5141 - val_root_mean_squared_error: 0.3424
# Epoch 49/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4897 - root_mean_squared_error: 0.3284 - val_loss: 0.5143 - val_root_mean_squared_error: 0.3424
# Epoch 50/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.4888 - root_mean_squared_error: 0.3279 - val_loss: 0.5143 - val_root_mean_squared_error: 0.3424
# Epoch 51/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4879 - root_mean_squared_error: 0.3274 - val_loss: 0.5137 - val_root_mean_squared_error: 0.3422
# Epoch 52/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4871 - root_mean_squared_error: 0.3269 - val_loss: 0.5134 - val_root_mean_squared_error: 0.3420
# Epoch 53/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4863 - root_mean_squared_error: 0.3264 - val_loss: 0.5123 - val_root_mean_squared_error: 0.3415
# Epoch 54/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.4854 - root_mean_squared_error: 0.3259 - val_loss: 0.5122 - val_root_mean_squared_error: 0.3415
# Epoch 55/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4846 - root_mean_squared_error: 0.3254 - val_loss: 0.5113 - val_root_mean_squared_error: 0.3411
# Epoch 56/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4838 - root_mean_squared_error: 0.3250 - val_loss: 0.5117 - val_root_mean_squared_error: 0.3412
# Epoch 57/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4830 - root_mean_squared_error: 0.3245 - val_loss: 0.5114 - val_root_mean_squared_error: 0.3411
# Epoch 58/200
# 786/786 [==============================] - 52s 66ms/step - loss: 0.4823 - root_mean_squared_error: 0.3241 - val_loss: 0.5104 - val_root_mean_squared_error: 0.3406
# Epoch 59/200
# 786/786 [==============================] - 52s 67ms/step - loss: 0.4815 - root_mean_squared_error: 0.3237 - val_loss: 0.5101 - val_root_mean_squared_error: 0.3405
# Epoch 60/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4808 - root_mean_squared_error: 0.3233 - val_loss: 0.5105 - val_root_mean_squared_error: 0.3407
# Epoch 61/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4801 - root_mean_squared_error: 0.3228 - val_loss: 0.5098 - val_root_mean_squared_error: 0.3404
# Epoch 62/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4793 - root_mean_squared_error: 0.3224 - val_loss: 0.5091 - val_root_mean_squared_error: 0.3400
# Epoch 63/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4786 - root_mean_squared_error: 0.3220 - val_loss: 0.5094 - val_root_mean_squared_error: 0.3402
# Epoch 64/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4779 - root_mean_squared_error: 0.3215 - val_loss: 0.5082 - val_root_mean_squared_error: 0.3396
# Epoch 65/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4773 - root_mean_squared_error: 0.3212 - val_loss: 0.5086 - val_root_mean_squared_error: 0.3399
# Epoch 66/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4766 - root_mean_squared_error: 0.3208 - val_loss: 0.5083 - val_root_mean_squared_error: 0.3397
# Epoch 67/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4759 - root_mean_squared_error: 0.3204 - val_loss: 0.5080 - val_root_mean_squared_error: 0.3395
# Epoch 68/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4753 - root_mean_squared_error: 0.3200 - val_loss: 0.5074 - val_root_mean_squared_error: 0.3393
# Epoch 69/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4746 - root_mean_squared_error: 0.3196 - val_loss: 0.5076 - val_root_mean_squared_error: 0.3394
# Epoch 70/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4740 - root_mean_squared_error: 0.3192 - val_loss: 0.5070 - val_root_mean_squared_error: 0.3391
# Epoch 71/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4734 - root_mean_squared_error: 0.3189 - val_loss: 0.5067 - val_root_mean_squared_error: 0.3389
# Epoch 72/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4728 - root_mean_squared_error: 0.3185 - val_loss: 0.5065 - val_root_mean_squared_error: 0.3389
# Epoch 73/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4722 - root_mean_squared_error: 0.3181 - val_loss: 0.5060 - val_root_mean_squared_error: 0.3386
# Epoch 74/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4716 - root_mean_squared_error: 0.3178 - val_loss: 0.5061 - val_root_mean_squared_error: 0.3387
# Epoch 75/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4710 - root_mean_squared_error: 0.3174 - val_loss: 0.5059 - val_root_mean_squared_error: 0.3386
# Epoch 76/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4704 - root_mean_squared_error: 0.3171 - val_loss: 0.5059 - val_root_mean_squared_error: 0.3386
# Epoch 77/200
# 786/786 [==============================] - 56s 72ms/step - loss: 0.4699 - root_mean_squared_error: 0.3168 - val_loss: 0.5057 - val_root_mean_squared_error: 0.3385
# Epoch 78/200
# 786/786 [==============================] - 56s 72ms/step - loss: 0.4693 - root_mean_squared_error: 0.3164 - val_loss: 0.5052 - val_root_mean_squared_error: 0.3383
# Epoch 79/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4687 - root_mean_squared_error: 0.3160 - val_loss: 0.5050 - val_root_mean_squared_error: 0.3382
# Epoch 80/200
# 786/786 [==============================] - 56s 72ms/step - loss: 0.4682 - root_mean_squared_error: 0.3157 - val_loss: 0.5045 - val_root_mean_squared_error: 0.3380
# Epoch 81/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4676 - root_mean_squared_error: 0.3154 - val_loss: 0.5049 - val_root_mean_squared_error: 0.3382
# Epoch 82/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4671 - root_mean_squared_error: 0.3151 - val_loss: 0.5046 - val_root_mean_squared_error: 0.3381
# Epoch 83/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4666 - root_mean_squared_error: 0.3148 - val_loss: 0.5051 - val_root_mean_squared_error: 0.3383
# Epoch 84/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4661 - root_mean_squared_error: 0.3145 - val_loss: 0.5043 - val_root_mean_squared_error: 0.3379
# Epoch 85/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4655 - root_mean_squared_error: 0.3141 - val_loss: 0.5040 - val_root_mean_squared_error: 0.3378
# Epoch 86/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4650 - root_mean_squared_error: 0.3138 - val_loss: 0.5040 - val_root_mean_squared_error: 0.3378
# Epoch 87/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4645 - root_mean_squared_error: 0.3135 - val_loss: 0.5037 - val_root_mean_squared_error: 0.3377
# Epoch 88/200
# 786/786 [==============================] - 55s 69ms/step - loss: 0.4640 - root_mean_squared_error: 0.3132 - val_loss: 0.5040 - val_root_mean_squared_error: 0.3378
# Epoch 89/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4635 - root_mean_squared_error: 0.3129 - val_loss: 0.5035 - val_root_mean_squared_error: 0.3376
# Epoch 90/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4630 - root_mean_squared_error: 0.3126 - val_loss: 0.5039 - val_root_mean_squared_error: 0.3378
# Epoch 91/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4625 - root_mean_squared_error: 0.3123 - val_loss: 0.5031 - val_root_mean_squared_error: 0.3374
# Epoch 92/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4620 - root_mean_squared_error: 0.3120 - val_loss: 0.5036 - val_root_mean_squared_error: 0.3377
# Epoch 93/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4616 - root_mean_squared_error: 0.3117 - val_loss: 0.5031 - val_root_mean_squared_error: 0.3374
# Epoch 94/200
# 786/786 [==============================] - 56s 72ms/step - loss: 0.4611 - root_mean_squared_error: 0.3114 - val_loss: 0.5028 - val_root_mean_squared_error: 0.3373
# Epoch 95/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4606 - root_mean_squared_error: 0.3112 - val_loss: 0.5030 - val_root_mean_squared_error: 0.3374
# Epoch 96/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4602 - root_mean_squared_error: 0.3108 - val_loss: 0.5024 - val_root_mean_squared_error: 0.3371
# Epoch 97/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4598 - root_mean_squared_error: 0.3106 - val_loss: 0.5030 - val_root_mean_squared_error: 0.3374
# Epoch 98/200
# 786/786 [==============================] - 57s 72ms/step - loss: 0.4593 - root_mean_squared_error: 0.3103 - val_loss: 0.5024 - val_root_mean_squared_error: 0.3371
# Epoch 99/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4588 - root_mean_squared_error: 0.3100 - val_loss: 0.5023 - val_root_mean_squared_error: 0.3371
# Epoch 100/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4584 - root_mean_squared_error: 0.3098 - val_loss: 0.5019 - val_root_mean_squared_error: 0.3369
# Epoch 101/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4579 - root_mean_squared_error: 0.3095 - val_loss: 0.5024 - val_root_mean_squared_error: 0.3372
# Epoch 102/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4575 - root_mean_squared_error: 0.3092 - val_loss: 0.5018 - val_root_mean_squared_error: 0.3369
# Epoch 103/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4571 - root_mean_squared_error: 0.3090 - val_loss: 0.5020 - val_root_mean_squared_error: 0.3370
# Epoch 104/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4566 - root_mean_squared_error: 0.3087 - val_loss: 0.5015 - val_root_mean_squared_error: 0.3367
# Epoch 105/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4562 - root_mean_squared_error: 0.3085 - val_loss: 0.5017 - val_root_mean_squared_error: 0.3368
# Epoch 106/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4558 - root_mean_squared_error: 0.3082 - val_loss: 0.5013 - val_root_mean_squared_error: 0.3366
# Epoch 107/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4554 - root_mean_squared_error: 0.3079 - val_loss: 0.5018 - val_root_mean_squared_error: 0.3370
# Epoch 108/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4550 - root_mean_squared_error: 0.3077 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3368
# Epoch 109/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4546 - root_mean_squared_error: 0.3075 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3368
# Epoch 110/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4542 - root_mean_squared_error: 0.3072 - val_loss: 0.5016 - val_root_mean_squared_error: 0.3369
# Epoch 111/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4538 - root_mean_squared_error: 0.3069 - val_loss: 0.5012 - val_root_mean_squared_error: 0.3366
# Epoch 112/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4534 - root_mean_squared_error: 0.3067 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3365
# Epoch 113/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4530 - root_mean_squared_error: 0.3065 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3368
# Epoch 114/200
# 786/786 [==============================] - 55s 69ms/step - loss: 0.4526 - root_mean_squared_error: 0.3062 - val_loss: 0.5013 - val_root_mean_squared_error: 0.3368
# Epoch 115/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4522 - root_mean_squared_error: 0.3060 - val_loss: 0.5010 - val_root_mean_squared_error: 0.3366
# Epoch 116/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4518 - root_mean_squared_error: 0.3057 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3369
# Epoch 117/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4515 - root_mean_squared_error: 0.3055 - val_loss: 0.5015 - val_root_mean_squared_error: 0.3369
# Epoch 118/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4511 - root_mean_squared_error: 0.3053 - val_loss: 0.5010 - val_root_mean_squared_error: 0.3367
# Epoch 119/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4507 - root_mean_squared_error: 0.3050 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3366
# Epoch 120/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4503 - root_mean_squared_error: 0.3048 - val_loss: 0.5012 - val_root_mean_squared_error: 0.3368
# Epoch 121/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4500 - root_mean_squared_error: 0.3046 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3368
# Epoch 122/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4495 - root_mean_squared_error: 0.3043 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3367
# Epoch 123/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4492 - root_mean_squared_error: 0.3041 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3368
# Epoch 124/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4489 - root_mean_squared_error: 0.3039 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3366
# Epoch 125/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4485 - root_mean_squared_error: 0.3037 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3365
# Epoch 126/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4481 - root_mean_squared_error: 0.3035 - val_loss: 0.5012 - val_root_mean_squared_error: 0.3369
# Epoch 127/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4478 - root_mean_squared_error: 0.3032 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3364
# Epoch 128/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4475 - root_mean_squared_error: 0.3030 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3367
# Epoch 129/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4471 - root_mean_squared_error: 0.3028 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3367
# Epoch 130/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4467 - root_mean_squared_error: 0.3026 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3369
# Epoch 131/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4464 - root_mean_squared_error: 0.3024 - val_loss: 0.5000 - val_root_mean_squared_error: 0.3362
# Epoch 132/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4460 - root_mean_squared_error: 0.3022 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3367
# Epoch 133/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4457 - root_mean_squared_error: 0.3019 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3365
# Epoch 134/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4454 - root_mean_squared_error: 0.3018 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3368
# Epoch 135/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4450 - root_mean_squared_error: 0.3015 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3365
# Epoch 136/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4447 - root_mean_squared_error: 0.3013 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3365
# Epoch 137/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4444 - root_mean_squared_error: 0.3011 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3367
# Epoch 138/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4441 - root_mean_squared_error: 0.3009 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3365
# Epoch 139/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4437 - root_mean_squared_error: 0.3007 - val_loss: 0.5001 - val_root_mean_squared_error: 0.3364
# Epoch 140/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4434 - root_mean_squared_error: 0.3005 - val_loss: 0.5006 - val_root_mean_squared_error: 0.3367
# Epoch 141/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4431 - root_mean_squared_error: 0.3003 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3367
# Epoch 142/200
# 786/786 [==============================] - 56s 71ms/step - loss: 0.4428 - root_mean_squared_error: 0.3001 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3366
# Epoch 143/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4425 - root_mean_squared_error: 0.2999 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3366
# Epoch 144/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4421 - root_mean_squared_error: 0.2997 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3367
# Epoch 145/200
# 786/786 [==============================] - 55s 70ms/step - loss: 0.4418 - root_mean_squared_error: 0.2995 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 146/200
# 786/786 [==============================] - 55s 71ms/step - loss: 0.4415 - root_mean_squared_error: 0.2993 - val_loss: 0.5006 - val_root_mean_squared_error: 0.3368
# Epoch 147/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4411 - root_mean_squared_error: 0.2991 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 148/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4408 - root_mean_squared_error: 0.2989 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3366
# Epoch 149/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4406 - root_mean_squared_error: 0.2988 - val_loss: 0.5006 - val_root_mean_squared_error: 0.3368
# Epoch 150/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4403 - root_mean_squared_error: 0.2986 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 151/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4400 - root_mean_squared_error: 0.2984 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3367
# Epoch 152/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4396 - root_mean_squared_error: 0.2982 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 153/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4393 - root_mean_squared_error: 0.2980 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3368
# Epoch 154/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4390 - root_mean_squared_error: 0.2978 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 155/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4388 - root_mean_squared_error: 0.2976 - val_loss: 0.5002 - val_root_mean_squared_error: 0.3366
# Epoch 156/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4384 - root_mean_squared_error: 0.2974 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3367
# Epoch 157/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4382 - root_mean_squared_error: 0.2973 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3367
# Epoch 158/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4379 - root_mean_squared_error: 0.2971 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3369
# Epoch 159/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4376 - root_mean_squared_error: 0.2969 - val_loss: 0.5002 - val_root_mean_squared_error: 0.3367
# Epoch 160/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4373 - root_mean_squared_error: 0.2967 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3368
# Epoch 161/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4370 - root_mean_squared_error: 0.2965 - val_loss: 0.5002 - val_root_mean_squared_error: 0.3367
# Epoch 162/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4368 - root_mean_squared_error: 0.2964 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3370
# Epoch 163/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4364 - root_mean_squared_error: 0.2962 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3370
# Epoch 164/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4362 - root_mean_squared_error: 0.2960 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3368
# Epoch 165/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4359 - root_mean_squared_error: 0.2959 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3371
# Epoch 166/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4356 - root_mean_squared_error: 0.2957 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3368
# Epoch 167/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4353 - root_mean_squared_error: 0.2955 - val_loss: 0.5002 - val_root_mean_squared_error: 0.3367
# Epoch 168/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4351 - root_mean_squared_error: 0.2953 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3369
# Epoch 169/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4348 - root_mean_squared_error: 0.2952 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3370
# Epoch 170/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4345 - root_mean_squared_error: 0.2950 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3372
# Epoch 171/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4343 - root_mean_squared_error: 0.2948 - val_loss: 0.5006 - val_root_mean_squared_error: 0.3370
# Epoch 172/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4340 - root_mean_squared_error: 0.2946 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3369
# Epoch 173/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4337 - root_mean_squared_error: 0.2945 - val_loss: 0.5003 - val_root_mean_squared_error: 0.3368
# Epoch 174/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4334 - root_mean_squared_error: 0.2943 - val_loss: 0.5005 - val_root_mean_squared_error: 0.3370
# Epoch 175/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4331 - root_mean_squared_error: 0.2941 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3371
# Epoch 176/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4329 - root_mean_squared_error: 0.2940 - val_loss: 0.5004 - val_root_mean_squared_error: 0.3369
# Epoch 177/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4326 - root_mean_squared_error: 0.2938 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3372
# Epoch 178/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4324 - root_mean_squared_error: 0.2936 - val_loss: 0.5006 - val_root_mean_squared_error: 0.3370
# Epoch 179/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4321 - root_mean_squared_error: 0.2935 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3371
# Epoch 180/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4319 - root_mean_squared_error: 0.2934 - val_loss: 0.5010 - val_root_mean_squared_error: 0.3373
# Epoch 181/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4316 - root_mean_squared_error: 0.2931 - val_loss: 0.5010 - val_root_mean_squared_error: 0.3373
# Epoch 182/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4313 - root_mean_squared_error: 0.2930 - val_loss: 0.5013 - val_root_mean_squared_error: 0.3374
# Epoch 183/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4311 - root_mean_squared_error: 0.2928 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3371
# Epoch 184/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4308 - root_mean_squared_error: 0.2927 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3373
# Epoch 185/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4306 - root_mean_squared_error: 0.2925 - val_loss: 0.5009 - val_root_mean_squared_error: 0.3372
# Epoch 186/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4303 - root_mean_squared_error: 0.2924 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3376
# Epoch 187/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4301 - root_mean_squared_error: 0.2922 - val_loss: 0.5007 - val_root_mean_squared_error: 0.3371
# Epoch 188/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4298 - root_mean_squared_error: 0.2921 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3374
# Epoch 189/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4296 - root_mean_squared_error: 0.2919 - val_loss: 0.5008 - val_root_mean_squared_error: 0.3372
# Epoch 190/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4293 - root_mean_squared_error: 0.2918 - val_loss: 0.5012 - val_root_mean_squared_error: 0.3374
# Epoch 191/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4291 - root_mean_squared_error: 0.2916 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3374
# Epoch 192/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4288 - root_mean_squared_error: 0.2915 - val_loss: 0.5013 - val_root_mean_squared_error: 0.3375
# Epoch 193/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4286 - root_mean_squared_error: 0.2913 - val_loss: 0.5010 - val_root_mean_squared_error: 0.3373
# Epoch 194/200
# 786/786 [==============================] - 53s 67ms/step - loss: 0.4284 - root_mean_squared_error: 0.2912 - val_loss: 0.5015 - val_root_mean_squared_error: 0.3376
# Epoch 195/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4281 - root_mean_squared_error: 0.2910 - val_loss: 0.5011 - val_root_mean_squared_error: 0.3374
# Epoch 196/200
# 786/786 [==============================] - 53s 68ms/step - loss: 0.4279 - root_mean_squared_error: 0.2909 - val_loss: 0.5016 - val_root_mean_squared_error: 0.3377
# Epoch 197/200
# 786/786 [==============================] - 54s 69ms/step - loss: 0.4277 - root_mean_squared_error: 0.2907 - val_loss: 0.5014 - val_root_mean_squared_error: 0.3376
# Epoch 198/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4274 - root_mean_squared_error: 0.2906 - val_loss: 0.5018 - val_root_mean_squared_error: 0.3378
# Epoch 199/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4272 - root_mean_squared_error: 0.2904 - val_loss: 0.5015 - val_root_mean_squared_error: 0.3376
# Epoch 200/200
# 786/786 [==============================] - 54s 68ms/step - loss: 0.4270 - root_mean_squared_error: 0.2903 - val_loss: 0.5015 - val_root_mean_squared_error: 0.3377

# %%
book_df = pd.DataFrame({
    'isbn':model_dl_df['isbn'],
    'book_title':model_dl_df['book_title'],
    'Category':model_dl_df['Category'],
})

# %%
book_df.duplicated().sum()
# Out:
# 717617

# %%
book_df.drop_duplicates(inplace=True)

# %%
book_df
# Out:
#                isbn  ...              Category
# 812571   0380794810  ...           ['Fiction']
# 204175   0385314698  ...           ['Fiction']
# 361064   0140444300  ...                     9
# 421248   0345413865  ...                     9
# 407734   1551669153  ...           ['Fiction']
# ...             ...  ...                   ...
# 531615   0140504427  ...  ['Juvenile Fiction']
# 963881   039923036X  ...  ['Juvenile Fiction']
# 829594   0759639787  ...                     9
# 959472   0312139454  ...           ['Fiction']
# 1002588  0679420606  ...                     9
#
# [264662 rows x 3 columns]

# %%
# Top rekomendasi buku untuk random user
user_id = model_dl_df.user_id.sample(10).iloc[0]
books_read_by_user = model_dl_df[model_dl_df.user_id == user_id]
books_not_read = book_df[~book_df['isbn'].isin(books_read_by_user.isbn.values)]['isbn']
books_not_read = list(
    set(books_not_read).intersection(set(book2book_encoded.keys()))
)

books_not_read = [[book2book_encoded.get(x)] for x in books_not_read]

user_encoder = user2user_encoded.get(user_id)

user_book_array = np.hstack(
    ([[user_encoder]] * len(books_not_read), books_not_read)
)

# %%
ratings = model.predict(user_book_array).flatten()

# %%
top_ratings_indices = ratings.argsort()[-10:][::-1]

recommended_book_ids = [
        book_encoded2book.get(books_not_read[x][0]) for x in top_ratings_indices
]

print("Showing recommendations for user: {}".format(user_id))
print("====" * 9)
print("Books with high ratings from user")
print("----" * 8)

top_books_user = (
    books_read_by_user.sort_values(
        by='rating', 
        ascending=False)
    .head(5)
    .isbn.values
)

book_df_rows = book_df[book_df["isbn"].isin(top_books_user)]
for row in book_df_rows.itertuples():
  print(row.book_title, ":", row.Category)

print("----" * 8)
print("Top 10 Books recommendations")
print("----" * 8)

recommended_books = book_df[book_df["isbn"].isin(recommended_book_ids)]
for row in recommended_books.itertuples():
  print(row.book_title, ":", row.Category)
# Out:
# Showing recommendations for user: 32440
# ====================================
# Books with high ratings from user
# --------------------------------
# a river runs through it and other stories  and other stories : ['Fiction']
# oracles and miracles : ['Fiction']
# danny the champion of the world puffin books : 9
# charlie and the great glass elevator puffin novels : ['Juvenile Fiction']
# the wind in the willows : ['Juvenile Fiction']
# --------------------------------
# Top 10 Books recommendations
# --------------------------------
# harry potter and the goblet of fire book  : ['Juvenile Fiction']
# falling up : ['Juvenile Nonfiction']
# its a magical world a calvin and hobbes collection : 9
# harry potter and the chamber of secrets postcard book : ['Juvenile Fiction']
# fox in socks i can read it all by myself beginner books : 9
# brief lives sandman book  : 9
# a kiss for little bear : 9
# the blue day book a lesson in cheering yourself up : 9
# free : ['Fiction']
# mittsommermord roman : 9

# %% [markdown]
# **Observasi :** <br>
# Dengan pendekatan Deep Learning, kita dapat melihat top 10 buku yang direkomendasikan untuk user dengan id 219951. Dari beberapa buku rekomendasi menyediakan kategori 'Fiction', '9', dan 'Juvenile Fiction' yang sesuai dengan rating user. Kita memperoleh 1 rekomendasi buku dengan kategori 'Fiction', 6 rekomendasi buku dengan kategori '9' dan 3 rekomendasi buku dengan kategori 'Juvenile Fiction'.

# %% [markdown]
# # **8. Evaluasi Model Deep learning atau Neural Network**

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.evaluate(x,y)
# Out:
# 30697/30697 [==============================] - 330s 11ms/step - loss: 0.4626 - root_mean_squared_error: 0.3117
# [0.46264955401420593, 0.31167978048324585]

# %% [markdown]
# **Observasi :** <br>
# Pada pembuatan proyek ini metrics evaluation yang digunakan yaitu root mean squared error (RMSE). Pada proses training model cukup smooth dan model konvergen pada epochs sekitar 200. Dari proses ini, kita memperoleh nilai error akhir sebesar sekitar 0.29 dan error pada data validasi sebesar 0.33. Nilai tersebut cukup bagus untuk sistem rekomendasi.
#
# Kemudian setelah dilakukan evaluasi menggunakan seluruh data memperoleh nilai error sebesar 0.31.

# %% [markdown]
# # **Penutup**
#
# Model untuk memberikan rekomendasi buku untuk pengguna telah selesai dibuat. Setelah diujikan, model ini bekerja cukup baik dalam memberikan 10 rekomendasi teratas terhadap buku berdasarkan preferensi pengguna sebelumnya.
#
#
# ### *Referensi*
# - https://towardsdatascience.com/prototyping-a-recommender-system-step-by-step-part-1-knn-item-based-collaborative-filtering-637969614ea
# - https://www.kaggle.com/ecemboluk/recommendation-system-with-cf-using-knn
# - https://www.kaggle.com/elahekamandi/recommendation-system-using-deep-learning
# - https://www.kaggle.com/nikitaredin/book-crossing-colloaborative-recommendation
# - https://www.kaggle.com/isaienkov/book-review-ratings-analysis-and-visualization
# - https://www.dicoding.com/academies/319
